# %% [markdown]
# <a href="https://colab.research.google.com/github/MansiPokiya/ORES_ass.mansipokiya/blob/main/Copy_of_Data_Transformation_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid19 = pd.read_csv('Excess_Deaths_Associated_with_COVID-19.csv')

# %%
print(len(covid19.columns))
covid19.columns
# Out:
# 14
# Index(['Week Ending Date', 'State', 'Observed Number', 'Upper Bound Threshold',
#        'Exceeds Threshold', 'Average Expected Count', 'Excess Estimate',
#        'Total Excess Estimate', 'Percent Excess Estimate', 'Year', 'Type',
#        'Outcome', 'Suppress', 'Note'],
#       dtype='object')

# %%
covid19.shape
# Out:
# (56700, 14)

# %%
covid19.ndim
# Out:
# 2

# %%
covid19.head()
# Out:
#   Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 0       2017-01-07  Alabama           1121.0                   1136
# 1       2017-01-14  Alabama           1130.0                   1140
# 2       2017-01-21  Alabama           1048.0                   1142
# 3       2017-01-28  Alabama           1026.0                   1142
# 4       2017-02-04  Alabama           1036.0                   1142
#
#    Exceeds Threshold  Average Expected Count  Excess Estimate  \
# 0              False                    1059               62
# 1              False                    1067               63
# 2              False                    1071                0
# 3              False                    1070                0
# 4              False                    1068                0
#
#    Total Excess Estimate  Percent Excess Estimate  Year                  Type  \
# 0                  29601                 5.852700  2017  Predicted (weighted)
# ...

# %%
covid19.describe()
# Out:
#        Observed Number  Upper Bound Threshold  Average Expected Count  \
# count     56685.000000           56700.000000             56700.00000
# mean       2176.866790            2185.994162              2081.42672
# std        7866.632085            7728.123535              7466.45743
# min          51.000000              97.000000                81.00000
# 25%         339.000000             363.000000               329.00000
# 50%         864.000000             895.000000               836.00000
# 75%        1428.000000            1460.000000              1373.00000
# max       87415.000000           63426.000000             61689.00000
#
#        Excess Estimate  Total Excess Estimate  Percent Excess Estimate  \
# count     56700.000000           5.670000e+04             56700.000000
# mean        118.867407           3.798794e+04                 5.977915
# std         863.135999           1.522219e+05                12.405099
# ...

# %%
#unique values in each column
unique_values = covid19.nunique()
print(len(unique_values))
print(unique_values)
# Out:
# 14
# Week Ending Date             350
# State                         54
# Observed Number             4634
# Upper Bound Threshold       3824
# Exceeds Threshold              2
# Average Expected Count      3752
# Excess Estimate             1280
# Total Excess Estimate        159
# Percent Excess Estimate    18103
# Year                           7
# Type                           2
# Outcome                        2
# Suppress                       1
# Note                           6
# dtype: int64

# %%
# drop unnecessary column from dataset
covid19 = covid19.drop(['Suppress'] ,axis=1)

# %%
covid19
# Out:
#       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 0           2017-01-07  Alabama           1121.0                   1136
# 1           2017-01-14  Alabama           1130.0                   1140
# 2           2017-01-21  Alabama           1048.0                   1142
# 3           2017-01-28  Alabama           1026.0                   1142
# 4           2017-02-04  Alabama           1036.0                   1142
# ...                ...      ...              ...                    ...
# 56695       2023-08-19  Wyoming            118.0                    115
# 56696       2023-08-26  Wyoming             76.0                    115
# 56697       2023-09-02  Wyoming             78.0                    115
# 56698       2023-09-09  Wyoming             76.0                    115
# 56699       2023-09-16  Wyoming             51.0                    114
#
#        Exceeds Threshold  Average Expected Count  Excess Estimate  \
# ...

# %%
column_data_types = covid19.dtypes
print(column_data_types)
# Out:
# Week Ending Date            object
# State                       object
# Observed Number            float64
# Upper Bound Threshold        int64
# Exceeds Threshold             bool
# Average Expected Count       int64
# Excess Estimate              int64
# Total Excess Estimate        int64
# Percent Excess Estimate    float64
# Year                         int64
# Type                        object
# Outcome                     object
# Note                        object
# dtype: object

# %%
covid19['Week Ending Date']=covid19['Week Ending Date'].astype('category')
covid19['State']=covid19['State'].astype('category')

# %%
covid19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56700 entries, 0 to 56699
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Week Ending Date         56700 non-null  category
#  1   State                    56700 non-null  category
#  2   Observed Number          56685 non-null  float64
#  3   Upper Bound Threshold    56700 non-null  int64
#  4   Exceeds Threshold        56700 non-null  bool
#  5   Average Expected Count   56700 non-null  int64
#  6   Excess Estimate          56700 non-null  int64
#  7   Total Excess Estimate    56700 non-null  int64
#  8   Percent Excess Estimate  56700 non-null  float64
#  9   Year                     56700 non-null  int64
#  10  Type                     56700 non-null  object
#  11  Outcome                  56700 non-null  object
#  12  Note                     14580 non-null  object
# ...

# %%
covid19.isnull()
# Out:
#        Week Ending Date  State  Observed Number  Upper Bound Threshold  \
# 0                 False  False            False                  False
# 1                 False  False            False                  False
# 2                 False  False            False                  False
# 3                 False  False            False                  False
# 4                 False  False            False                  False
# ...                 ...    ...              ...                    ...
# 56695             False  False            False                  False
# 56696             False  False            False                  False
# 56697             False  False            False                  False
# 56698             False  False            False                  False
# 56699             False  False            False                  False
#
#        Exceeds Threshold  Average Expected Count  Excess Estimate  \
# ...

# %%
covid19=covid19.dropna()
covid19
# Out:
#       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 260         2022-01-01  Alabama           1253.0                   1172
# 261         2022-01-08  Alabama           1330.0                   1177
# 262         2022-01-15  Alabama           1521.0                   1182
# 263         2022-01-22  Alabama           1500.0                   1180
# 264         2022-01-29  Alabama           1697.0                   1181
# ...                ...      ...              ...                    ...
# 56695       2023-08-19  Wyoming            118.0                    115
# 56696       2023-08-26  Wyoming             76.0                    115
# 56697       2023-09-02  Wyoming             78.0                    115
# 56698       2023-09-09  Wyoming             76.0                    115
# 56699       2023-09-16  Wyoming             51.0                    114
#
#        Exceeds Threshold  Average Expected Count  Excess Estimate  \
# ...

# %%
# Rename columns
covid19_cleaned = covid19.rename(columns={'Week Ending Date': 'Week_Ending_Date', 'State': 'state', 'Observed Number': 'Observed_Number','Upper Bound Threshold':'Upper_Bound_Threshold','Exceeds Threshold':'Exceeds_Threshold','Average Expected Count':'Average_Expected_Count','Excess Estimate':'Excess_Estimate','Total Excess Estimate':'Total_Excess_Estimate','Percent Excess Estimate	':'Percent_Excess_Estimate','Year':'year','Type':'type','Outcome':'outcome'})

# %%
covid19.rename
# Out:
# <bound method DataFrame.rename of       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 260         2022-01-01  Alabama           1253.0                   1172
# 261         2022-01-08  Alabama           1330.0                   1177
# 262         2022-01-15  Alabama           1521.0                   1182
# 263         2022-01-22  Alabama           1500.0                   1180
# 264         2022-01-29  Alabama           1697.0                   1181
# ...                ...      ...              ...                    ...
# 56695       2023-08-19  Wyoming            118.0                    115
# 56696       2023-08-26  Wyoming             76.0                    115
# 56697       2023-09-02  Wyoming             78.0                    115
# 56698       2023-09-09  Wyoming             76.0                    115
# 56699       2023-09-16  Wyoming             51.0                    114
#
#        Exceeds Threshold  Average Expected Count  Excess Estimate  \
# ...

# %%
covid19['Average Excess Estimate'] = covid19['Total Excess Estimate'] - covid19['Excess Estimate']
covid19
# Out:
# <ipython-input-70-2303e3a1e546>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 260         2022-01-01  Alabama           1253.0                   1172
# 261         2022-01-08  Alabama           1330.0                   1177
# 262         2022-01-15  Alabama           1521.0                   1182
# 263         2022-01-22  Alabama           1500.0                   1180
# 264         2022-01-29  Alabama           1697.0                   1181
# ...                ...      ...              ...                    ...
# 56695       2023-08-19  Wyoming            118.0                    115
# ...

# %%
duplicate = covid19.duplicated()
print(duplicate)
# Out:
# 260      False
# 261      False
# 262      False
# 263      False
# 264      False
#          ...
# 56695    False
# 56696    False
# 56697    False
# 56698    False
# 56699    False
# Length: 14565, dtype: bool

# %%
covid19.describe()
# Out:
#        Observed Number  Upper Bound Threshold  Average Expected Count  \
# count     14565.000000           14565.000000            14565.000000
# mean       2241.805630            2246.549056             2146.608926
# std        8085.597865            7914.504213             7669.209428
# min          51.000000             107.000000               90.000000
# 25%         355.000000             369.000000              336.000000
# 50%         895.000000             934.000000              878.000000
# 75%        1469.000000            1503.000000             1418.000000
# max       85747.000000           63426.000000            61689.000000
#
#        Excess Estimate  Total Excess Estimate  Percent Excess Estimate  \
# count     14565.000000           1.456500e+04             14565.000000
# mean        118.568005           3.801724e+04                 5.645202
# std         804.467745           1.523009e+05                 8.656556
# ...

# %%
covid19.to_csv('cleaned_data_of_covid.csv',index=False)
print(covid19.head())
# Out:
#     Week Ending Date    State  Observed Number  Upper Bound Threshold  \
# 260       2022-01-01  Alabama           1253.0                   1172
# 261       2022-01-08  Alabama           1330.0                   1177
# 262       2022-01-15  Alabama           1521.0                   1182
# 263       2022-01-22  Alabama           1500.0                   1180
# 264       2022-01-29  Alabama           1697.0                   1181
#
#      Exceeds Threshold  Average Expected Count  Excess Estimate  \
# 260               True                    1112              141
# 261               True                    1117              213
# 262               True                    1122              399
# 263               True                    1120              380
# 264               True                    1122              575
#
#      Total Excess Estimate  Percent Excess Estimate  Year  \
# 260                  29601                12.684951  2022
# ...
